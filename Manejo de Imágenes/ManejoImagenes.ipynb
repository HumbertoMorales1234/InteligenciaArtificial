# %%
import cv2 as cv
import numpy as np

# %%
img = cv.imread('C:/Users/betov/OneDrive/Escritorio/imgsIA/lordVader.jpg', 0)
#el número a continuación indica los colores que se muestran en la imagen.
img2 = img.copy()
img3 = img.copy()
img4 = img.copy()
img5 = img.copy()
cv.imshow('Ejemplo_Antes_Filtro', img)
w,h = (img.shape)
for i in range(w):
    for j in range (h):
        img[i,j]= img[i,j]/2
        img2[i,j]= 255-img2[i,j] #Calcula el negativo
        if( img3[i,j]>150):
            img3[i,j]=0
        else:
            img3[i,j]=255
        if(img4[i,j]>0 and img4[i,j]<255):
            img4[i,j]= 150
        #img5[i,j]= img5[w-i,h-j]
        
cv.imshow('Filtro_1', img)
cv.imshow('Filtro_2', img2)
cv.imshow('Filtro_3', img3)
cv.imshow('Filtro_4', img4)
cv.imshow('Filtro_5', img5)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

img = cv.imread('C:/Users/betov/OneDrive/Escritorio/imgsIA/acuarella.jpg',)
zeros = np.zeros(img.shape[:2], dtype='uint8')
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
(b,g,r)=cv.split(img)
cv.imshow('Blue', b)
cv.imshow('Green', g)
cv.imshow('Red', r)
cv.imshow('B2', cv.merge([b, zeros, zeros]))
cv.imshow('G2', cv.merge([zeros, g, zeros]))
cv.imshow('R2', cv.merge([zeros, zeros, r]))
cv.imshow('Original', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Filtrar el color e indicar las coordenadas en las que aparece ese color

import cv2 as cv
import numpy as np
img = cv.imread('C:/Users/betov/OneDrive/Escritorio/imgsIA/f1.jpg',1)
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img3 = cv.cvtColor(img2, cv.COLOR_RGB2HSV)

umbralRojoBajo=(0,80,80)
umbralRojoAlto=(10,255,255)
umbralRojoBajob=(140,80,80)
umbralRojoAltob=(255,255,255)

umbralBajoAmarillo = (20,80,80)
umbralAltoAmarillo = (40,255,255)

mascara1Rojo= cv.inRange(img3, umbralRojoBajo, umbralRojoAlto) # Resalta los colores rojos
mascara2Rojo= cv.inRange(img3, umbralRojoBajob, umbralRojoAltob) # Resalta los colores rojos
mascaraRojo= mascara1Rojo+mascara2Rojo
resultadoRojo = cv.bitwise_and(img, img, mask=mascaraRojo)

mascaraAmarillo = cv.inRange(img3, umbralBajoAmarillo, umbralAltoAmarillo)
resultadoAmarillo = cv.bitwise_and(img, img, mask=mascaraAmarillo)

cv.imshow('Resultado Rojo', resultadoRojo)
cv.imshow('Normal', img)
cv.imshow('Resultado Amarillo', resultadoAmarillo)

contornosR, _ = cv.findContours(mascaraRojo, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contornosA, _ = cv.findContours(mascaraAmarillo, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# Inicializar una lista para almacenar las coordenadas de los colores rojos
coordenadasRojo = []
coordenadasAmarillo = []

# Recorrer los contornos y obtener las coordenadas del centro de cada contorno
for contorno in contornosR:
    momentos = cv.moments(contorno)
    if momentos["m00"] != 0:
        x = int(momentos["m10"] / momentos["m00"])
        y = int(momentos["m01"] / momentos["m00"])
        coordenadasRojo.append((x, y))
        
for contorno in contornosA:
    momentos = cv.moments(contorno)
    if momentos["m00"] != 0:
        x = int(momentos["m10"] / momentos["m00"])
        y = int(momentos["m01"] / momentos["m00"])
        coordenadasAmarillo.append((x, y))

print('Coordenadas rojos:')
print(coordenadasRojo)
print('Coordenadas Amarillas')
print(coordenadasAmarillo)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Coordenadas rojos:
# ...

# %%
import cv2 as cv
import numpy as np
cap = cv.VideoCapture(0)
if not cap.isOpened():
    print('No se pudo acceder a la cámara')
    exit()
while True:
    ret, img = cap.read()
    img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img3 = cv.cvtColor(img2, cv.COLOR_RGB2HSV)

    umbralbajo=(80,80,80)
    umbralalto=(140,255,255)
    #umbralbajob=(170,80,80)
    #umbralaltob=(180,255,255)

    mascara= cv.inRange(img3, umbralbajo, umbralalto) # Resalta los colores rojos
    #mascara2= cv.inRange(img3, umbralbajob, umbralaltob) # Resalta los colores rojos
    #mascara= mascara1+mascara2
    resultado = cv.bitwise_and(img, img, mask=mascara)

    cv.imshow('img', img)
    cv.imshow('img2', img2)
    cv.imshow('img3', img3)
    cv.imshow('mascara', mascara)
    cv.imshow('resultado', resultado)
    if cv.waitKey(1) == ord('q'):
        break
cap.release()
cv.destroyAllWindows()

# %%
# Filtrar el color e indicar las coordenadas en las que aparece ese color

import cv2 as cv
import numpy as np
img = cv.imread('C:/Users/betov/OneDrive/Escritorio/imgsIA/carretera.webp',1)
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img3 = cv.cvtColor(img2, cv.COLOR_RGB2HSV)

umbralBlancoBajo=(20,20,200)
umbralBlancoAlto=(255,40,255)

mascara= cv.inRange(img3, umbralBlancoBajo, umbralBlancoAlto) # Resalta los colores rojos
resultadoBlanco = cv.bitwise_and(img, img, mask=mascara)

cv.imshow('Resultado Rojo', resultadoBlanco)
cv.imshow('Normal', img)

contornosB, _ = cv.findContours(mascara, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# Inicializar una lista para almacenar las coordenadas de los colores rojos
coordenadasBlanco = []

# Recorrer los contornos y obtener las coordenadas del centro de cada contorno
for contorno in contornosB:
    momentos = cv.moments(contorno)
    if momentos["m00"] != 0:
        x = int(momentos["m10"] / momentos["m00"])
        y = int(momentos["m01"] / momentos["m00"])
        coordenadasBlanco.append((x, y))


print('Coordenadas rojos:')
print(coordenadasBlanco)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Coordenadas rojos:
# ...

# %%
import cv2 as cv
import numpy as np

img = cv.imread('C:/Users/betov/OneDrive/Escritorio/imgsIA/carretera.webp', 0) 
w,h= (img.shape)


for i in range(w):
    for j in range(h):
        img[i, j] = 255-img[i,j]

cv.imshow('carretera', img)


umbralBajo = (0)
umbralAlto = (100)

mascara= cv.inRange(img, umbralBajo, umbralAlto) # Resalta los colores rojos
resultado = cv.bitwise_and(img, img, mask=mascara)

cv.imshow('Resultado', resultado)
cv.waitKey(0)
cv.destroyAllWindows()
